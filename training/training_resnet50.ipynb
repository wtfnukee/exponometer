# %%
import pandas as pd
from PIL import Image, PngImagePlugin
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import models, transforms
import pytorch_lightning as pl
import torch
from torch import nn
from lightning.pytorch import Trainer
from lightning.pytorch.loggers import TensorBoardLogger
from torchmetrics.classification import Accuracy
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

PngImagePlugin.MAX_TEXT_CHUNK = int(1e15)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:128: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
df = pd.read_parquet('../new_images_path_all.parquet.gzip')
len(df)
# Out:
# 26974

# %%
class ImageDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        label = row['Id_typology']
        img = Image.open(f"/home/jupyter/datasphere/project/{row['Img_folder']}/{row['Img_path']}")
        
        if self.transform:
            img = self.transform(img)
        return img, label

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
BATCH_SIZE = 64

dataset = ImageDataset(df, transform=transform)
train_set, val_set = torch.utils.data.random_split(dataset, [0.75, 0.25])
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, num_workers=4, pin_memory=True)

logger = TensorBoardLogger("transfer_learn_logs", name="resnet")

# %%
class ImageClassifier(pl.LightningModule):
    def __init__(self):
        super().__init__()
        backbone = models.resnet50(weights="DEFAULT")
        num_filters = backbone.fc.in_features
        layers = list(backbone.children())[:-1]
        self.feature_extractor = nn.Sequential(*layers)
        self.feature_extractor.eval()
        self.classifier = nn.Linear(num_filters, 15)
        self.criterion = nn.CrossEntropyLoss()
        self.accuracy = Accuracy(task="multiclass", num_classes=15)

    def forward(self, x):
        with torch.no_grad():
            representations = self.feature_extractor(x).flatten(1)
        x = self.classifier(representations)
        return x

    def training_step(self, batch, batch_idx):
        images, labels = batch
        outputs = self(images)
        loss = self.criterion(outputs, labels)
        # correct = outputs.argmax(dim=1).eq(labels).sum().item()
        accuracy = self.accuracy(outputs, labels)
        logs = {'loss': loss, 'accuracy': accuracy}
        self.log_dict(logs, logger=True)
        return logs
    
    def validation_step(self, batch, batch_idx):
        images, labels = batch 
        outputs = self(images) 
        loss = self.criterion(outputs, labels.view(-1))
        # correct = outputs.argmax(dim=1).eq(labels).sum().item()
        accuracy = self.accuracy(outputs, labels)
        logs = {"val_loss": loss, "val_accuracy": accuracy}
        self.log_dict(logs, logger=True)
        return logs

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# %%
model = ImageClassifier()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /tmp/xdg_cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 66.3MB/s]

# %%
trainer = pl.Trainer(
    max_epochs=80,
    accelerator='gpu' if torch.cuda.is_available() else 'cpu',
    devices=1,
    logger=logger,
    log_every_n_steps=317,
    callbacks=[EarlyStopping(monitor="val_loss", mode="min", patience=5)],
    enable_checkpointing=True
)

trainer.fit(model, train_loader, val_loader)
# trainer.save_checkpoint("final.ckpt")
# trainer.fit(model, train_loader, val_loader, ckpt_path="./transfer_learn_logs/resnet/version_0/checkpoints/epoch=7-step=1272.ckpt")
# Out:
# Epoch 1: 100%|██████████| 317/317 [11:06<00:00,  0.48it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:02, 43.01it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:02<02:15,  0.77it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:02<01:30,  1.14it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:02<01:07,  1.50it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:07<02:33,  0.66it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:12<03:34,  0.47it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:12<03:02,  0.54it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:12<02:38,  0.62it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:17<03:05,  0.52it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:21<03:21,  0.48it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:21<03:01,  0.52it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:22<02:53,  0.54it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:26<03:07,  0.50it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:28<03:07,  0.49it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:28<02:53,  0.53it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:28<02:42,  0.55it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [00:34<03:01,  0.49it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [00:35<02:55,  0.50it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [00:39<02:59,  0.48it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [00:39<02:48,  0.51it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [00:40<02:42,  0.52it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [00:45<02:53,  0.48it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [00:47<02:52,  0.48it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [00:47<02:43,  0.50it/s]
# Validation DataLoader 0:  24%|██▎       | 25/106 [00:49<02:40,  0.50it/s]
# Validation DataLoader 0:  25%|██▍       | 26/106 [00:52<02:40,  0.50it/s]
# Validation DataLoader 0:  25%|██▌       | 27/106 [00:56<02:46,  0.47it/s]
# Validation DataLoader 0:  26%|██▋       | 28/106 [00:57<02:38,  0.49it/s]
# Validation DataLoader 0:  27%|██▋       | 29/106 [00:57<02:31,  0.51it/s]
# Validation DataLoader 0:  28%|██▊       | 30/106 [00:57<02:25,  0.52it/s]
# Validation DataLoader 0:  29%|██▉       | 31/106 [01:04<02:34,  0.48it/s]
# Validation DataLoader 0:  30%|███       | 32/106 [01:04<02:28,  0.50it/s]
# Validation DataLoader 0:  31%|███       | 33/106 [01:04<02:23,  0.51it/s]
# Validation DataLoader 0:  32%|███▏      | 34/106 [01:04<02:17,  0.52it/s]
# Validation DataLoader 0:  33%|███▎      | 35/106 [01:13<02:29,  0.47it/s]
# Validation DataLoader 0:  34%|███▍      | 36/106 [01:13<02:23,  0.49it/s]
# Validation DataLoader 0:  35%|███▍      | 37/106 [01:16<02:23,  0.48it/s]
# Validation DataLoader 0:  36%|███▌      | 38/106 [01:16<02:17,  0.49it/s]

# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:02, 46.25it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:03<02:41,  0.64it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:03<01:47,  0.96it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:03<01:20,  1.27it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:07<02:36,  0.64it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:13<03:51,  0.43it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:13<03:16,  0.50it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:13<02:50,  0.57it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:17<03:05,  0.52it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:22<03:36,  0.44it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:22<03:14,  0.49it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:22<02:57,  0.53it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:26<03:07,  0.50it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:30<03:17,  0.47it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:30<03:02,  0.50it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:30<02:49,  0.53it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [00:35<03:03,  0.49it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [00:37<03:01,  0.48it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [00:39<03:02,  0.48it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [00:39<02:51,  0.50it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [00:40<02:44,  0.52it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [00:46<02:59,  0.47it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [00:48<02:53,  0.48it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [00:48<02:44,  0.50it/s]
# Validation DataLoader 0:  24%|██▎       | 25/106 [00:50<02:42,  0.50it/s]
# Validation DataLoader 0:  25%|██▍       | 26/106 [00:53<02:44,  0.49it/s]
# Validation DataLoader 0:  25%|██▌       | 27/106 [00:57<02:48,  0.47it/s]
# Validation DataLoader 0:  26%|██▋       | 28/106 [00:57<02:40,  0.49it/s]
# Validation DataLoader 0:  27%|██▋       | 29/106 [00:57<02:33,  0.50it/s]
# Validation DataLoader 0:  28%|██▊       | 30/106 [00:58<02:28,  0.51it/s]
# Validation DataLoader 0:  29%|██▉       | 31/106 [01:04<02:36,  0.48it/s]
# Validation DataLoader 0:  30%|███       | 32/106 [01:04<02:29,  0.49it/s]
# Validation DataLoader 0:  31%|███       | 33/106 [01:05<02:25,  0.50it/s]
# Validation DataLoader 0:  32%|███▏      | 34/106 [01:05<02:19,  0.52it/s]
# Validation DataLoader 0:  33%|███▎      | 35/106 [01:15<02:32,  0.47it/s]

# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:02, 35.72it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:01<01:06,  1.56it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:02<01:20,  1.29it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:02<00:59,  1.70it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:15<05:08,  0.33it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:18<05:16,  0.32it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:18<04:28,  0.37it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:18<03:52,  0.42it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:33<06:00,  0.27it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:34<05:31,  0.29it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:34<04:58,  0.32it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:36<04:44,  0.33it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:50<05:57,  0.26it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:50<05:28,  0.28it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:50<05:03,  0.30it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:51<04:48,  0.31it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [01:06<05:45,  0.26it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [01:06<05:23,  0.27it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [01:06<05:04,  0.29it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [01:07<04:49,  0.30it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [01:20<05:26,  0.26it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [01:20<05:07,  0.27it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [01:21<04:53,  0.28it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [01:22<04:42,  0.29it/s]
# Validation DataLoader 0:  24%|██▎       | 25/106 [01:35<05:10,  0.26it/s]
# Validation DataLoader 0:  25%|██▍       | 26/106 [01:35<04:54,  0.27it/s]
# Validation DataLoader 0:  25%|██▌       | 27/106 [01:37<04:44,  0.28it/s]
# Validation DataLoader 0:  26%|██▋       | 28/106 [01:37<04:30,  0.29it/s]
# Validation DataLoader 0:  27%|██▋       | 29/106 [01:47<04:45,  0.27it/s]
# Validation DataLoader 0:  28%|██▊       | 30/106 [01:47<04:32,  0.28it/s]
# Validation DataLoader 0:  29%|██▉       | 31/106 [01:49<04:25,  0.28it/s]
# Validation DataLoader 0:  30%|███       | 32/106 [01:49<04:14,  0.29it/s]
# Validation DataLoader 0:  96%|█████████▌| 102/106 [06:45<00:15,  0.25it/s]
# Validation DataLoader 0:  97%|█████████▋| 103/106 [06:45<00:11,  0.25it/s]
# Validation DataLoader 0:  98%|█████████▊| 104/106 [06:45<00:07,  0.26it/s]
# Validation DataLoader 0:  99%|█████████▉| 105/106 [06:53<00:03,  0.25it/s]
# Validation DataLoader 0: 100%|██████████| 106/106 [06:53<00:00,  0.26it/s]
# Epoch 4: 100%|██████████| 317/317 [14:00<00:00,  0.38it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:04, 23.81it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:02<02:10,  0.80it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:02<01:40,  1.03it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:02<01:15,  1.35it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:07<02:36,  0.65it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:12<03:30,  0.48it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:12<02:58,  0.55it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:12<02:35,  0.63it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:16<03:00,  0.54it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:20<03:17,  0.49it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:20<02:57,  0.53it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:22<02:58,  0.53it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:25<03:00,  0.52it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:28<03:08,  0.49it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:28<02:53,  0.52it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:30<02:48,  0.53it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [00:33<02:57,  0.50it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [00:35<02:54,  0.51it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [00:38<02:56,  0.49it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [00:38<02:45,  0.52it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [00:39<02:39,  0.53it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [00:45<02:53,  0.48it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [00:46<02:47,  0.49it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [00:47<02:40,  0.51it/s]
# Validation DataLoader 0:  24%|██▎       | 25/106 [00:48<02:37,  0.51it/s]
# Validation DataLoader 0:  25%|██▍       | 26/106 [00:51<02:39,  0.50it/s]
# Validation DataLoader 0:  25%|██▌       | 27/106 [00:56<02:44,  0.48it/s]
# Validation DataLoader 0:  26%|██▋       | 28/106 [00:56<02:36,  0.50it/s]
# Validation DataLoader 0:  27%|██▋       | 29/106 [00:56<02:29,  0.51it/s]
# Validation DataLoader 0:  28%|██▊       | 30/106 [00:57<02:25,  0.52it/s]
# Validation DataLoader 0:  94%|█████████▍| 100/106 [03:27<00:12,  0.48it/s]
# Validation DataLoader 0:  95%|█████████▌| 101/106 [03:29<00:10,  0.48it/s]
# Validation DataLoader 0:  96%|█████████▌| 102/106 [03:29<00:08,  0.49it/s]
# Validation DataLoader 0:  97%|█████████▋| 103/106 [03:33<00:06,  0.48it/s]
# Validation DataLoader 0:  98%|█████████▊| 104/106 [03:33<00:04,  0.49it/s]
# Validation DataLoader 0:  99%|█████████▉| 105/106 [03:34<00:02,  0.49it/s]
# Validation DataLoader 0: 100%|██████████| 106/106 [03:34<00:00,  0.49it/s]
# Epoch 5: 100%|██████████| 317/317 [11:23<00:00,  0.46it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:03, 34.51it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:02<02:32,  0.68it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:02<01:41,  1.02it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:02<01:15,  1.35it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:07<02:36,  0.64it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:13<03:45,  0.44it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:13<03:11,  0.52it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:13<02:46,  0.59it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:17<03:05,  0.52it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:21<03:24,  0.47it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:21<03:04,  0.52it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:22<02:55,  0.53it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:26<03:07,  0.50it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:28<03:09,  0.49it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:28<02:55,  0.52it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:28<02:42,  0.55it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [00:34<03:02,  0.49it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [00:35<02:55,  0.50it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [00:39<02:59,  0.48it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [00:39<02:49,  0.51it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [00:40<02:44,  0.52it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [00:45<02:55,  0.48it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [00:47<02:51,  0.48it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [00:47<02:42,  0.50it/s]
# Validation DataLoader 0:  24%|██▎       | 25/106 [00:49<02:40,  0.50it/s]
# Validation DataLoader 0:  25%|██▍       | 26/106 [00:52<02:41,  0.50it/s]
# Validation DataLoader 0:  25%|██▌       | 27/106 [00:56<02:46,  0.47it/s]
# Validation DataLoader 0:  92%|█████████▏| 97/106 [03:24<00:18,  0.48it/s]
# Validation DataLoader 0:  92%|█████████▏| 98/106 [03:24<00:16,  0.48it/s]
# Validation DataLoader 0:  93%|█████████▎| 99/106 [03:28<00:14,  0.47it/s]
# Validation DataLoader 0:  94%|█████████▍| 100/106 [03:28<00:12,  0.48it/s]
# Validation DataLoader 0:  95%|█████████▌| 101/106 [03:30<00:10,  0.48it/s]
# Validation DataLoader 0:  96%|█████████▌| 102/106 [03:30<00:08,  0.48it/s]
# Validation DataLoader 0:  97%|█████████▋| 103/106 [03:34<00:06,  0.48it/s]
# Validation DataLoader 0:  98%|█████████▊| 104/106 [03:34<00:04,  0.48it/s]
# Validation DataLoader 0:  99%|█████████▉| 105/106 [03:36<00:02,  0.48it/s]
# Validation DataLoader 0: 100%|██████████| 106/106 [03:36<00:00,  0.49it/s]
# Epoch 6: 100%|██████████| 317/317 [11:07<00:00,  0.47it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:03, 30.41it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:03<02:47,  0.62it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:03<01:50,  0.93it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:03<01:22,  1.23it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:07<02:32,  0.66it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:13<03:51,  0.43it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:13<03:16,  0.50it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:13<02:50,  0.57it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:16<03:03,  0.53it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:22<03:33,  0.45it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:22<03:12,  0.49it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:24<03:08,  0.50it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:26<03:06,  0.50it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:30<03:18,  0.46it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:30<03:03,  0.50it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:30<02:53,  0.52it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [00:34<03:02,  0.49it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [00:37<03:01,  0.49it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [00:39<03:02,  0.48it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [00:39<02:51,  0.50it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [00:40<02:44,  0.52it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [00:47<02:59,  0.47it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [00:47<02:52,  0.48it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [00:47<02:43,  0.50it/s]
# Validation DataLoader 0:  24%|██▎       | 25/106 [00:49<02:41,  0.50it/s]
# Validation DataLoader 0:  90%|████████▉ | 95/106 [03:22<00:23,  0.47it/s]
# Validation DataLoader 0:  91%|█████████ | 96/106 [03:22<00:21,  0.47it/s]
# Validation DataLoader 0:  92%|█████████▏| 97/106 [03:26<00:19,  0.47it/s]
# Validation DataLoader 0:  92%|█████████▏| 98/106 [03:26<00:16,  0.48it/s]
# Validation DataLoader 0:  93%|█████████▎| 99/106 [03:28<00:14,  0.47it/s]
# ...
# Validation DataLoader 0:  96%|█████████▌| 102/106 [03:35<00:08,  0.47it/s]
# Validation DataLoader 0:  97%|█████████▋| 103/106 [03:39<00:06,  0.47it/s]
# Validation DataLoader 0:  98%|█████████▊| 104/106 [03:39<00:04,  0.47it/s]
# Validation DataLoader 0:  99%|█████████▉| 105/106 [03:41<00:02,  0.47it/s]
# Validation DataLoader 0: 100%|██████████| 106/106 [03:41<00:00,  0.48it/s]
# Epoch 8: 100%|██████████| 317/317 [11:22<00:00,  0.46it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/106 [00:00<?, ?it/s]
# Validation DataLoader 0:   1%|          | 1/106 [00:00<00:04, 21.62it/s]
# Validation DataLoader 0:   2%|▏         | 2/106 [00:02<02:17,  0.76it/s]
# Validation DataLoader 0:   3%|▎         | 3/106 [00:02<01:31,  1.13it/s]
# Validation DataLoader 0:   4%|▍         | 4/106 [00:02<01:10,  1.45it/s]
# Validation DataLoader 0:   5%|▍         | 5/106 [00:07<02:36,  0.64it/s]
# Validation DataLoader 0:   6%|▌         | 6/106 [00:13<03:42,  0.45it/s]
# Validation DataLoader 0:   7%|▋         | 7/106 [00:13<03:09,  0.52it/s]
# Validation DataLoader 0:   8%|▊         | 8/106 [00:13<02:44,  0.60it/s]
# Validation DataLoader 0:   8%|▊         | 9/106 [00:16<03:02,  0.53it/s]
# Validation DataLoader 0:   9%|▉         | 10/106 [00:21<03:24,  0.47it/s]
# Validation DataLoader 0:  10%|█         | 11/106 [00:21<03:04,  0.51it/s]
# Validation DataLoader 0:  11%|█▏        | 12/106 [00:22<02:59,  0.52it/s]
# Validation DataLoader 0:  12%|█▏        | 13/106 [00:25<03:05,  0.50it/s]
# Validation DataLoader 0:  13%|█▎        | 14/106 [00:29<03:11,  0.48it/s]
# Validation DataLoader 0:  14%|█▍        | 15/106 [00:29<02:56,  0.51it/s]
# Validation DataLoader 0:  15%|█▌        | 16/106 [00:30<02:50,  0.53it/s]
# Validation DataLoader 0:  16%|█▌        | 17/106 [00:35<03:03,  0.48it/s]
# Validation DataLoader 0:  17%|█▋        | 18/106 [00:36<02:58,  0.49it/s]
# Validation DataLoader 0:  18%|█▊        | 19/106 [00:40<03:03,  0.47it/s]
# Validation DataLoader 0:  19%|█▉        | 20/106 [00:40<02:52,  0.50it/s]
# Validation DataLoader 0:  20%|█▉        | 21/106 [00:41<02:46,  0.51it/s]
# Validation DataLoader 0:  21%|██        | 22/106 [00:46<02:58,  0.47it/s]
# Validation DataLoader 0:  22%|██▏       | 23/106 [00:48<02:55,  0.47it/s]
# Validation DataLoader 0:  23%|██▎       | 24/106 [00:48<02:46,  0.49it/s]
# Validation DataLoader 0:  89%|████████▊ | 94/106 [03:20<00:25,  0.47it/s]
# Validation DataLoader 0:  90%|████████▉ | 95/106 [03:25<00:23,  0.46it/s]
# Validation DataLoader 0:  91%|█████████ | 96/106 [03:25<00:21,  0.47it/s]
# Validation DataLoader 0:  92%|█████████▏| 97/106 [03:26<00:19,  0.47it/s]
# Validation DataLoader 0:  92%|█████████▏| 98/106 [03:26<00:16,  0.47it/s]
# Validation DataLoader 0:  93%|█████████▎| 99/106 [03:32<00:15,  0.47it/s]
# Validation DataLoader 0:  94%|█████████▍| 100/106 [03:32<00:12,  0.47it/s]
# Validation DataLoader 0:  95%|█████████▌| 101/106 [03:33<00:10,  0.47it/s]
# Validation DataLoader 0:  96%|█████████▌| 102/106 [03:33<00:08,  0.48it/s]
# Validation DataLoader 0:  97%|█████████▋| 103/106 [03:38<00:06,  0.47it/s]
# Validation DataLoader 0:  98%|█████████▊| 104/106 [03:38<00:04,  0.48it/s]
# Validation DataLoader 0:  99%|█████████▉| 105/106 [03:40<00:02,  0.48it/s]
# Validation DataLoader 0: 100%|██████████| 106/106 [03:40<00:00,  0.48it/s]
# Epoch 9:  73%|███████▎  | 230/317 [08:22<03:10,  0.46it/s, v_num=1]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_8828/884400649.py in <cell line: 11>()
#       9 )
#      10
# ---> 11 trainer.fit(model, train_loader, val_loader)
#      12 # trainer.save_checkpoint("final.ckpt")
#      13 # trainer.fit(model, train_loader, val_loader, ckpt_path="./transfer_learn_logs/resnet/version_0/checkpoints/epoch=7-step=1272.ckpt")
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536         self.state.status = TrainerStatus.RUNNING
#     537         self.training = True
# --> 538         call._call_and_handle_interrupt(
#     539             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540         )
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      45         if trainer.strategy.launcher is not None:
#      46             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47         return trainer_fn(*args, **kwargs)
#      48
#      49     except _TunerExitException:
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     572             model_connected=self.lightning_module is not None,
#     573         )
# --> 574         self._run(model, ckpt_path=ckpt_path)
#     575
#     576         assert self.state.stopped
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in _run(self, model, ckpt_path)
#     979         # RUN THE TRAINER
#     980         # ----------------------------
# --> 981         results = self._run_stage()
#     982
#     983         # ----------------------------
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py in _run_stage(self)
#    1023                 self._run_sanity_check()
#    1024             with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025                 self.fit_loop.run()
#    1026             return None
#    1027         raise RuntimeError(f"Unexpected state {self.state}")
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py in run(self)
#     203             try:
#     204                 self.on_advance_start()
# --> 205                 self.advance()
#     206                 self.on_advance_end()
#     207                 self._restarting = False
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py in advance(self)
#     361         with self.trainer.profiler.profile("run_training_epoch"):
#     362             assert self._data_fetcher is not None
# --> 363             self.epoch_loop.run(self._data_fetcher)
#     364
#     365     def on_advance_end(self) -> None:
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/loops/training_epoch_loop.py in run(self, data_fetcher)
#     138         while not self.done:
#     139             try:
# --> 140                 self.advance(data_fetcher)
#     141                 self.on_advance_end(data_fetcher)
#     142                 self._restarting = False
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/loops/training_epoch_loop.py in advance(self, data_fetcher)
#     210         else:
#     211             dataloader_iter = None
# --> 212             batch, _, __ = next(data_fetcher)
#     213             # TODO: we should instead use the batch_idx returned by the fetcher, however, that will require saving the
#     214             # fetcher state so that the batch_idx is correct after restarting
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/loops/fetchers.py in __next__(self)
#     131         elif not self.done:
#     132             # this will run only when no pre-fetching was done.
# --> 133             batch = super().__next__()
#     134         else:
#     135             # the iterator is empty
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/loops/fetchers.py in __next__(self)
#      58         self._start_profiler()
#      59         try:
# ---> 60             batch = next(self.iterator)
#      61         except StopIteration:
#      62             self.done = True
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/utilities/combined_loader.py in __next__(self)
#     339     def __next__(self) -> _ITERATOR_RETURN:
#     340         assert self._iterator is not None
# --> 341         out = next(self._iterator)
#     342         if isinstance(self._iterator, _Sequential):
#     343             return out
#
# ~/.local/lib/python3.10/site-packages/pytorch_lightning/utilities/combined_loader.py in __next__(self)
#      76         for i in range(n):
#      77             try:
# ---> 78                 out[i] = next(self.iterators[i])
#      79             except StopIteration:
#      80                 self._consumed[i] = True
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1443             if len(self._task_info[self._rcvd_idx]) == 2:
#    1444                 data = self._task_info.pop(self._rcvd_idx)[1]
# -> 1445                 return self._process_data(data)
#    1446
#    1447             assert not self._shutdown and self._tasks_outstanding > 0
#
# ~/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1489         self._try_put_index()
#    1490         if isinstance(data, ExceptionWrapper):
# -> 1491             data.reraise()
#    1492         return data
#    1493
#
# ~/.local/lib/python3.10/site-packages/torch/_utils.py in reraise(self)
#     713             # instantiate since we don't know how to
#     714             raise RuntimeError(msg) from None
# --> 715         raise exception
#     716
#     717
#
# PermissionError: Caught PermissionError in DataLoader worker process 2.
# Original Traceback (most recent call last):
#   File "/home/jupyter/.local/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 351, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#   File "/home/jupyter/.local/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 50, in fetch
#     data = self.dataset.__getitems__(possibly_batched_index)
#   File "/home/jupyter/.local/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 420, in __getitems__
#     return [self.dataset[self.indices[idx]] for idx in indices]
#   File "/home/jupyter/.local/lib/python3.10/site-packages/torch/utils/data/dataset.py", line 420, in <listcomp>
#     return [self.dataset[self.indices[idx]] for idx in indices]
#   File "/tmp/ipykernel_8828/3777491006.py", line 12, in __getitem__
#     img = Image.open(f"/home/jupyter/datasphere/project/{row['Img_folder']}/{row['Img_path']}")
#   File "/usr/local/lib/python3.10/dist-packages/PIL/Image.py", line 3227, in open
#     fp = builtins.open(filename, "rb")
# PermissionError: [Errno 13] Permission denied: '/home/jupyter/datasphere/project/images_path30k/29487.png'

# %%
type_id = pd.read_parquet('new_type_id.parquet.gzip')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
import seaborn as sns

def draw_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=type_id['typology'], yticklabels=['typology'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
